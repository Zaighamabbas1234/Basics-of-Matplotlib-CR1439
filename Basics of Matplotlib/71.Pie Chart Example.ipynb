# %%
import numpy as np
import matplotlib as pyplot
from matplotlib import pyplot as plt

# %%
students_name = ["Ali","Sam","Jhon","Alia","Afia"]
marks = (50,100,150,200,250)

# %%
plt.pie(marks, labels = students_name)
plt.show()
