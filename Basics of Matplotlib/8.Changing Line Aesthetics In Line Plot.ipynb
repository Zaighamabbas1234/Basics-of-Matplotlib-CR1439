# %%
# Changing line aesthetics in line plot:-

# %%
# plt.plot(x,y, color="color name", linestyle="sign", linewidth=value)

# plt.title("Line Plot")
# plt.xlabel("x-label")
# plt.ylabel("y-label")

# plt.show()
