# %%
# Changing asthetics in doughnut chart:-

# %%
# Plt.pie(variable name, lables = variable name,radius = value, autopct = "%0.1f%%", colour = ["colours name"]).
# Plt.pie([any random value], color ["white"], radius = value).
# ply.show().
