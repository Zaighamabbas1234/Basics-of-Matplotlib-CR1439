# %%
# Changing asthetics in pie chart example:-

# %%
# Plt.pie(variable name, lables = variable name, autopct = "%0.1f%%", colour = ["colours name"]).
# ply.show().

# %%
# autopct = "%0.1f%%" This shows the number of the digits after the decimal point.
