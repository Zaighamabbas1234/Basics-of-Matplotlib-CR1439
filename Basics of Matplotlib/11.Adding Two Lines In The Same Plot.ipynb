# %%
# Adding two linies in the same plot:-

# %%
# plt.plot(x,y, color="color name", linestyle="sign", linewidth=value)
# plt.plot(y,z, color="color name", linestyle="sign", linewidth=value)

# plt.title("Line Plot")
# plt.xlabel("x-label")
# plt.ylabel("y-label")
#plt.grid(True)                 Grid shows the boxes inside the graph.

# plt.show()
