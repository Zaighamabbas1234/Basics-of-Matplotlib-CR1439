# %%
# Changing line aesthetics in histogram:-

# %%
# plt.hist(x,color = "color name", bins = value)               (bins shows the number of boxes in the histogram).

# plt.title("Histogram")
# plt.xlabel("x-label")
# plt.ylabel("y-label")
# plt.grid("True")

# plt.show()
