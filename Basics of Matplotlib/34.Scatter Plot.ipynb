# %%
# Scatter plot:-

# %%
# We will always use the:-
#       plt.scatter(variables)                 x,y,z
#       plt.show

# %%
# x,y variables for two-dimensional.
# x,y,z variables for three-dimensional (space).
