# %%
# Doughnut chart:-

# %%
# It works as the pie chart.

# %%
# Plt.pie(variable name, lables = variable name, radius = value).
# Plt.pie([any random value], color ["white"], radius = value).
# ply.show().
