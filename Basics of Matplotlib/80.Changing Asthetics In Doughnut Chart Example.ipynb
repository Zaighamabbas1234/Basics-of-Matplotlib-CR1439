# %%
import numpy as np
import matplotlib as pyplot
from matplotlib import pyplot as plt

# %%
students_name = ["Ali","Sam","Jhon","Alia","Afia"]
marks = (50,100,150,200,250)

# %%
plt.pie(marks, labels = students_name, radius = 2, colors = ["Red","blue","Gray","Yellow","Pinks"], autopct = "0%.1f%%")
plt.pie([1],radius = 1, colors = ["black"])
plt.show()
