# %%
import numpy as np
import pandas as pd
import matplotlib as pyplot
from matplotlib import pyplot as plt

# %%
n_1 = [11,2,5,4,5]
n_2 =[6,7,7,2,6]
n_3 = [11,11,13,14,1]
n_1,n_2,n_3
# Out:
# ([11, 2, 5, 4, 5], [6, 7, 7, 2, 6], [11, 11, 13, 14, 1])

# %%
data = list([n_1,n_2,n_3])

# %%
plt.boxplot(data)
plt.show()
