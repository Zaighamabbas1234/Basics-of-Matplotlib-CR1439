# %%
import numpy as np
import matplotlib as pyplot
from matplotlib import pyplot as plt

# %%
fruits = ["Apple","Banana","Gava","Mango","Kavi"]
quantity = (10,20,30,40,50)

# %%
plt.pie(quantity, labels = fruits, colors = ["Red","Blue","Green","Yellow","Skyblue"], autopct = "0%.1f%%")
plt.show()
