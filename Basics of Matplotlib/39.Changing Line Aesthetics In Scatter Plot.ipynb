# %%
# Changing line aesthetics in scatter plot:-

# %%
# plt.scatter(x,y, color="color name", marker="sign", s(size)=value)

# plt.title("Scatter Plot")
# plt.xlabel("x-label")
# plt.ylabel("y-label")

# plt.show()
